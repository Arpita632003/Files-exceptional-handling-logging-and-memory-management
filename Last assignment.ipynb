# %%
 What is the difference between interpreted and compiled languages

Compiled Languages
Definition: Source code is translated entirely into machine code (binary) by a compiler before it is run.

Execution: The compiled file (e.g., .exe) is executed directly by the machine.

Examples: C, C++, Rust, Go
Interpreted Languages
Definition: Source code is executed line by line by an interpreter at runtime.

Execution: No separate machine code is generated beforehand.

Examples: Python, JavaScript, Ruby, PHP

# %%
 What is exception handling in Python
Exception handling in Python is a way to deal with errors that occur while a program is running, without crashing the program.

# %%
 What is the purpose of the finally block in exception handling
Always runs — whether:

An exception is raised and caught

An exception is raised and not caught

No exception is raised at all

Commonly used to:

Close files

Release resources (e.g., database connections)

Cleanup tasks

# %%
 What is logging in Python
Logging in Python is the process of recording messages that describe events that happen when a program runs. It's a way to track the flow of a program and debug issues — especially in production systems where you can't use print() statements.

# %%
 What is the significance of the __del__ method in Python
The __del__ method in Python is a special method called a destructor. It's automatically invoked when an object is about to be destroyed, i.e., when it’s about to be garbage-collected.

# %%
 What is the difference between import and from ... import in Python
Feature	import	from ... import
Imports	Whole module	Specific function/class/var
Usage	module.name	name directly
Namespace Pollution	Safer (less pollution)	Riskier if overused
Readability	More explicit	More concise
Performance	No major difference usually	Slight benefit if importing 1 item in large module

# %%
 How can you handle multiple exceptions in Python
In Python, you can handle multiple exceptions in several ways using the try and except blocks. This is useful when you expect more than one type of error and want to handle them differently or together.

# %%
 What is the purpose of the with statement when handling files in Python
The with statement in Python is used to simplify file handling and ensure that resources like files are properly managed — especially when it comes to closing the file automatically, even if an error occurs.

# %%
 What is the difference between multithreading and multiprocessing
1. Multithreading
Runs multiple threads within a single process

Threads share the same memory space

Useful for I/O-bound tasks (e.g., file operations, web scraping
                             Multiprocessing
Runs multiple processes, each with its own Python interpreter and memory space

Useful for CPU-bound tasks (e.g., image processing, data analysis)

# %%
 What are the advantages of using logging in a program
Tracks Events for Debugging & Monitoring
Helps you understand what your program is doing

Records runtime information, inputs, outputs, and internal state
Different Log Levels
Supports built-in severity levels:

DEBUG, INFO, WARNING, ERROR, CRITICAL

Allows you to filter logs based on importance
3. Logs to Files, Not Just Console
Saves logs to files for later analysis

Useful in production environments

python
Copy
Edit

# %%
 What is memory management in Python
Automatic Memory Management
Python uses automatic memory management, so you don't need to manually allocate or free memory like in C/C++.

Reference Counting
Every Python object keeps track of how many references point to it. When the reference count drops to zero, the object’s memory is freed.

Garbage Collection
Python has a garbage collector to clean up objects involved in reference cycles (where two or more objects reference each other).

Memory Pools
Python uses an internal allocator called PyMalloc to manage small objects efficiently.

# %%
 What are the basic steps involved in exception handling in Python
Step	Description
try	Write code that may raise an exception
except	Catch and handle specific exceptions
else (optional)	Run if no exceptions were raised
finally (optional)	Run cleanup code no matter what

# %%
 Why is memory management important in Python
Importance	Explanation
Resource Efficiency	Makes best use of limited memory
Prevent Memory Leaks	Avoids holding unused memory
Performance	Faster allocation and deallocation
Stability	Prevents crashes in long-running programs
Debugging	Helps identify and fix memory-related issues

# %%
 What is the role of try and except in exception handling
try	Encapsulates code that may raise an exception
except	Catches and handles specific exceptions raised in try

# %%
 How does Python's garbage collection system work
 Reference Counting
Every Python object keeps a count of how many references point to it.

When the reference count drops to zero, the memory for that object is immediately deallocated.

python
Copy
Edit
Cycle Detector (Garbage Collector)
Reference counting cannot detect cyclic references (e.g., objects referencing each other).

Python’s gc module runs a cycle detector to find and clean these cycles periodically.

# %%
 What is the purpose of the else block in exception handling
To write code that should execute only when the try block succeeds without errors.

Keeps the try block focused on the code that might raise exceptions.

Helps separate normal execution from error handling.

 What are the common logging levels in Python
DEBUG	10	Detailed information, for diagnosing problems	Development and troubleshooting
INFO	20	Confirmation that things are working as expected	General runtime events
WARNING	30	An indication something unexpected happened, or might cause problems	Minor issues, but program continues
ERROR	40	Serious problems that caused a failure in some part of the program	Exceptions and errors that affect functionality
CRITICAL	50	Very severe errors that may cause the program to stop running	Fatal errors, system crashes

# %%
 What is the difference between os.fork() and multiprocessing in Python
os.fork()
What it does:
os.fork() creates a new child process by duplicating the current process. The child process is almost an exact copy of the parent.

How it works:
It is a low-level system call available on Unix-like systems (Linux, macOS). It returns twice:

0 in the child process

The child’s PID (process ID) in the parent process
multiprocessing Module
What it does:
Provides a high-level API to create and manage separate processes, similar to threading but with true parallelism.

How it works:
Works on both Unix and Windows, abstracts away low-level OS calls, and provides features like:

Process creation

Inter-process communication (queues, pipes)

Process pools

Synchronization primitives (locks, events)

# %%
 What is the importance of closing a file in Python
 Frees System Resources
Files are backed by file descriptors provided by the operating system.

If too many files are left open, you may hit the system’s file limit, causing errors.

2. Flushes Write Buffers
When writing to a file, Python may buffer the data.

Calling .close() ensures that all buffered data is written to disk.

Without closing the file, some data might be lost or not saved properly.

python
Copy
Edit

# %%
 What is the difference between file.read() and file.readline() in Python
Reads	Whole file or specific number of chars	One line at a time
Return Type	Single string	Single line string
Newline Handling	Can contain multiple lines	Keeps \n at the end of each line
Best For	Reading entire file at once	Reading line-by-line (e.g., large files)
Memory Efficiency	Less efficient for large files	More efficient for large files

# %%
 What is the logging module in Python used for
Track Events at Runtime
Logs messages during code execution to understand what’s happening inside the application.

Helps identify what went wrong and when.

2. Record Different Levels of Importance
The module supports multiple log levels:

DEBUG – Detailed information for debugging

INFO – General information (e.g., program start)

WARNING – An unexpected event that’s not critical

ERROR – A serious problem that affects functionality

CRITICAL – A very serious error that may stop the program

3. Write Logs to Different Destinations
Console (standard output)

Log files

External systems (e.g., syslog, HTTP server, email)

python
Copy
Edit
import logging

logging.basicConfig(filename='app.log', level=logging.INFO)
logging.info("Application started")
4. Helps in Debugging and Maintenance
Instead of using print(), logs provide timestamped, categorized messages.

Useful in production environments where print() isn’t practical or sufficient.

5. Supports Formatting and Customization
You can customize log messages to include:

Timestamps

Log levels

Line numbers

# %%
 
 How would you catch and handle division by zero error in Python
try:
    numerator = int(input("Enter numerator: "))
    denominator = int(input("Enter denominator: "))
    result = numerator / denominator
    print(f"Result: {result}")
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")

# %%
 Write a Python program that logs an error message to a log file when a division by zero exception occurs
import logging

# Configure logging to write to a file
logging.basicConfig(
    filename='error_log.txt',
    level=logging.ERROR,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

try:
    numerator = int(input("Enter numerator: "))
    denominator = int(input("Enter denominator: "))
    result = numerator / denominator
    print(f"Result: {result}")

except ZeroDivisionError as e:
    print("Error: Cannot divide by zero.")
    logging.error("Attempted to divide by zero.", exc_info=True)

except ValueError:
    print("Error: Invalid input. Please enter integers only.")
    logging.error("Invalid input en

# %%
 How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module
import logging

# Configure logging
logging.basicConfig(
    filename='app.log',            # Log file name
    level=logging.DEBUG,           # Minimum level to log
    format='%(asctime)s - %(levelname)s - %(message)s'
)

# Log messages at different levels
logging.debug("This is a debug message.")
logging.info("Application has started.")
logging.warning("Low disk space warning.")
logging.error("An error occurred while saving the file.")
logging.critical("System is down!")

# %%
 Write a program to handle a file opening error using exception handling
filename = "example.txt"

try:
    with open(filename, 'r') as file:
        content = file.read()
        print("File content:")
        print(content)
except FileNotFoundError:
    print(f"Error: The file '{filename}' does not exist.")
except IOError as e:
    print(f"An I/O error occurred: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")

# %%
 How can you read a file line by line and store its content in a list in Python
filename = "example.txt"

lines = []
with open(filename, 'r') as file:
    for line in file:
        lines.append(line.rstrip('\n'))  # Remove trailing newline characters

print(lines)

# %%
 How can you append data to an existing file in Python
with open("example.txt", "a") as file:
    file.write("This line will be appended.\n")

# %%
Write a Python program that uses a try-except block to handle an error when attempting to access a 
dictionary key that doesn't exist
my_dict = {"name": "Alice", "age": 30}

key_to_access = "address"

try:
    value = my_dict[key_to_access]
    print(f"The value for '{key_to_access}' is: {value}")
except KeyError:
    print(f"Error: The key '{key_to_access}' does not exist in the dictionary.")

# %%
 Write a program that demonstrates using multiple except blocks to handle different types of exceptions
try:
    num1 = int(input("Enter the numerator: "))
    num2 = int(input("Enter the denominator: "))
    result = num1 / num2
    print(f"Result: {result}")

except ZeroDivisionError:
    print("Error: Cannot divide by zero.")

except ValueError:
    print("Error: Please enter valid integers.")

except Exception as e:
    print(f"An unexpected error occurred: {e}")

# %%
 How would you check if a file exists before attempting to read it in Python
import os

filename = 'example.txt'

if os.path.exists(filename):
    with open(filename, 'r') as file:
        content = file.read()
        print(content)
else:
    print(f"The file '{filename}' does not exist.")

# %%
 Write a program that uses the logging module to log both informational and error messages
import logging

# Configure logging: logs will be saved to 'app.log' with a specific format
logging.basicConfig(
    filename='app.log',
    level=logging.DEBUG,  # Capture all levels DEBUG and above
    format='%(asctime)s - %(levelname)s - %(message)s'
)

def divide_numbers(a, b):
    logging.info(f"Attempting to divide {a} by {b}")
    try:
        result = a / b
        logging.info(f"Division successful: result is {result}")
        return result
    except ZeroDivisionError:
        logging.error("Error: Division by zero attempted.")
        return None

# Example usage
divide_numbers(10, 2)  # Should log info messages
divide_numbers(10, 0)  # Should log an error message

# %%
 Write a Python program that prints the content of a file and handles the case when the file is empty
filename = "example.txt"

try:
    with open(filename, 'r') as file:
        content = file.read()
        if content:
            print("File content:")
            print(content)
        else:
            print(f"The file '{filename}' is empty.")
except FileNotFoundError:
    print(f"Error: The file '{filename}' does not exist.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
 Demonstrate how to use memory profiling to check the memory usage of a small program
from memory_profiler import profile

@profile
def my_function():
    a = [i for i in range(100000)]  # Allocate a big list
    b = [x * 2 for x in a]
    del a
    return b

if __name__ == "__main__":
    my_function()

# %%
 Write a Python program to create and write a list of numbers to a file, one number per line
numbers = [10, 20, 30, 40, 50]

filename = "numbers.txt"

with open(filename, 'w') as file:
    for number in numbers:
        file.write(f"{number}\n")

print(f"Numbers have been written to '{filename}'.")

# %%
 How would you implement a basic logging setup that logs to a file with rotation after 1MB
import logging
from logging.handlers import RotatingFileHandler

# Create logger
logger = logging.getLogger("MyLogger")
logger.setLevel(logging.DEBUG)  # Log everything DEBUG level and above

# Create a rotating file handler: max 1MB per file, keep 3 backups
handler = RotatingFileHandler(
    "app.log", maxBytes=1_000_000, backupCount=3
)

# Create a formatter and set it for the handler
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

# Add the handler to the logger
logger.addHandler(handler)

# Example logging calls
logger.info("This is an info message.")
logger.error("This is an error message.")

# %%
 Write a program that handles both IndexError and KeyError using a try-except block
my_list = [1, 2, 3]
my_dict = {"a": 10, "b": 20}

try:
    # Attempt to access an invalid index
    print(my_list[5])
    
    # Attempt to access a non-existent dictionary key
    print(my_dict["z"])

except IndexError:
    print("Error: List index is out of range.")

except KeyError:
    print("Error: Dictionary key does not exist.")

# %%
 How would you open a file and read its contents using a context manager in Python
filename = "example.txt"

with open(filename, 'r') as file:
    contents = file.read()

print(contents)

# %%
 Write a Python program that reads a file and prints the number of occurrences of a specific word
filename = "example.txt"
word_to_count = "python"

try:
    with open(filename, 'r') as file:
        text = file.read().lower()  # Read entire file and convert to lowercase

    count = text.split().count(word_to_count.lower())  # Count occurrences

    print(f"The word '{word_to_count}' appears {count} times in '{filename}'.")

except FileNotFoundError:
    print(f"Error: The file '{filename}' does not exist.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
 How can you check if a file is empty before attempting to read its contents
